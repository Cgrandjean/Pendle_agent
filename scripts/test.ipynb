# %%
import sys
sys.path.insert(0, '..')
from agents import pendle_mcp
import json

# %%
l=await pendle_mcp.get_markets(
                # chain_id=1,
                # filters=filters,
                sort_field="details_impliedApy",
                sort_dir="desc",
                # limit=MARKET_LIMIT,
            )

# %%
len(l)
# Out:
# 50

# %%
[e for e in l if "stables" in json.loads(e['categoryIds'])]
# Out:
# [{'address': '0xc325608dd3b0cdb7b0f08608ff9e6bf54e67f421',
#   'chainId': 999,
#   'name': 'AVLT',
#   'symbol': 'PENDLE-LPT',
#   'expiry': '2026-05-21T00:00:00.000Z',
#   'pt': '999-0xd1c248248552e1d33afafd5893beded07da0ee95',
#   'yt': '999-0xa36a3c6a1f1c48ab4d822b7527b0029fd373e2cf',
#   'sy': '999-0x3a853dfaf48053ebf890797227e08e9a3fb7b1f7',
#   'underlyingAsset': '999-0xd0ee0cf300dfb598270cd7f4d0c6e0d8f6e13f29',
#   'protocol': 'Altura Trade',
#   'isPrime': 0,
#   'categoryIds': '["stables","rwa","points"]',
#   'details_liquidity': 3388638.5706448024,
#   'details_totalTvl': 4028581.5948272194,
#   'details_tradingVolume': 128864.40001260248,
#   'details_underlyingApy': 0.19131464843536716,
#   'details_swapFeeApy': 0.0033987431133739587,
#   'details_pendleApy': 0.010126353784411147,
#   'details_impliedApy': 0.18740173146013483,
#   'details_aggregatedApy': 0.2967238390245629,
#   'details_maxBoostedApy': 0.45349422205455886,
# ...
